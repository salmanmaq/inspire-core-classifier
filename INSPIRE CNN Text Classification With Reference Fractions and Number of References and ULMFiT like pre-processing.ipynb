# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import nltk
import random
import numpy as np
from collections import Counter, OrderedDict
import nltk
import re
from copy import deepcopy
flatten = lambda l: [item for sublist in l for item in sublist]

import matplotlib.pyplot as plt
import itertools
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split

#random.seed(1024)
# %matplotlib inline

pd.options.display.max_rows=1000

# %%
USE_CUDA = torch.cuda.is_available()
gpus = [0]
torch.cuda.set_device(gpus[0])

FloatTensor = torch.cuda.FloatTensor if USE_CUDA else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if USE_CUDA else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if USE_CUDA else torch.ByteTensor

# %%
def getBatch_MultiHead(batch_size, train_data):
    random.shuffle(train_data)
    sindex = 0
    eindex = batch_size
    while eindex < len(train_data):
        batch = train_data[sindex: eindex]
        temp = eindex
        eindex = eindex + batch_size
        sindex = temp
        yield batch
    
    if eindex >= len(train_data):
        batch = train_data[sindex:]
        yield batch

# %%
def pad_to_batch_MultiHead(batch):
    x_text, x_ref, y, x_text_actual = zip(*batch)
    max_x_text = max([s.size(1) for s in x_text])
    x_p_text = []
    x_p_text_actual = []
    for i in range(len(batch)):
        if x_text[i].size(1) < max_x_text:
            x_p_text.append(torch.cat([x_text[i], Variable(LongTensor([inspire_data_stoi['_pad_']] * (max_x_text - x_text[i].size(1)))).view(1, -1)], 1))
        else:
            x_p_text.append(x_text[i])
        x_p_text_actual.append(x_text_actual)
    return torch.cat(x_p_text), torch.cat(x_ref), torch.cat(y).view(-1), x_p_text_actual

# %%
from fastai.text import (
    num_cpus,
    Tokenizer,
    partition_by_cores
)
from concurrent.futures import ProcessPoolExecutor
import re
from spacy.lang.en import English
from spacy.symbols import ORTH
import html
import collections

class FastLoadTokenizer(Tokenizer):
    """
    Tokenizer which avoids redundant loading of spacy language model

    The FastAI Tokenizer class loads all the pipeline components of the spacy model which significantly increases
    loading time, especially when doing inference on CPU. This class inherits from the FastAI Tokenizer and is
    refactored to avoid redundant loading of the classifier.
    """
    def __init__(self):
        self.re_br = re.compile(r'<\s*br\s*/?>', re.IGNORECASE)
        self.tok = English()
        for w in ('<eos>', '<bos>', '<unk>'):
            self.tok.tokenizer.add_special_case(w, [{ORTH: w}])

    def proc_all(self, ss):
        return [self.proc_text(s) for s in ss]

    def proc_all_mp(self, ss, ncpus=None):
        ncpus = ncpus or num_cpus() // 2
        with ProcessPoolExecutor(ncpus) as executor:
            return sum(executor.map(self.proc_all, ss), [])
# Out:
# /root/py36venv/lib64/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
re1 = re.compile(r'  +')
BOS = 'xbos'  # beginning-of-sentence tag
FLD = 'xfld'  # data field tag


def get_texts(df):
    labels = df['labels'].values.astype(np.int64)
    texts = f'\n{BOS} {FLD} 1 ' + df['text'].astype(str)
    texts = list(texts.apply(fixup).values)

    tokens = FastLoadTokenizer().proc_all_mp(partition_by_cores(texts))
    return tokens, list(labels)


def fixup(x):
    x = x.replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>', 'u_n').replace(' @.@ ', '.').replace(
        ' @-@ ', '-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x))

# %% [markdown]
# ## Data Loading and Pre-processing

# %%
inspire_data = pd.read_pickle('inspire_data_with_reference_fractions_and_num_references/inspire_data_with_reference_fractions_and_num_references.df')

# %%
inspire_data.iloc[:,:-2] = (inspire_data.iloc[:,:-2] - inspire_data.iloc[:,:-2].mean().values) / inspire_data.iloc[:,:-2].std().values

# %%
training_dataframe, validation_dataframe = train_test_split(inspire_data, test_size=0.2)#, random_state=123)

# %%
training_tokens, training_labels = get_texts(training_dataframe)
validation_tokens, validation_labels = get_texts(validation_dataframe)

# %%
MAX_VOCAB_SIZE = 60000
MINIMUM_FREQUENCY = 2

word_frequency = collections.Counter(p for o in training_tokens for p in o)
inspire_data_itos = [o for o, c in word_frequency.most_common(MAX_VOCAB_SIZE) if c > MINIMUM_FREQUENCY]
inspire_data_itos.insert(0, '_pad_')
inspire_data_itos.insert(0, '_unk_')
inspire_data_stoi = collections.defaultdict(lambda: 0, {v: k for k, v in enumerate(inspire_data_itos)})

training_token_ids = np.array([[inspire_data_stoi[o] for o in p] for p in training_tokens])
validation_token_ids = np.array([[inspire_data_stoi[o] for o in p] for p in validation_tokens])

# %%
X_train = training_token_ids
X_train_core1 = list(training_dataframe['core_references_fraction_first_order'])
X_train_core2 = list(training_dataframe['core_references_fraction_second_order'])
X_train_noncore1 = list(training_dataframe['noncore_references_fraction_first_order'])
X_train_noncore2 = list(training_dataframe['noncore_references_fraction_second_order'])
X_train_num_refs1 = list(training_dataframe['total_first_order_references'])
X_train_num_refs2 = list(training_dataframe['total_second_order_references'])
y_train = training_labels

# %%
# Get the class weights
rejected_count = y_train.count(0)
noncore_count = y_train.count(1)
core_count = y_train.count(2)

total_count = len(y_train)

inverse_rejected_fraction = total_count / rejected_count
inverse_noncore_fraction = total_count / noncore_count
inverse_core_fraction = total_count / core_count 

sum_fractions = inverse_rejected_fraction + inverse_noncore_fraction + inverse_core_fraction

# Specify the class weights (for the loss function specified later)
class_weights = torch.cuda.FloatTensor((inverse_rejected_fraction/sum_fractions,
                                        inverse_noncore_fraction/sum_fractions,
                                        inverse_core_fraction/sum_fractions))

# %%
class_weights = class_weights / class_weights[1]
print(class_weights)
# Out:
# tensor([1.8822, 1.0000, 1.1139], device='cuda:0')

# %%
X_val = validation_token_ids
X_val_core1 = list(validation_dataframe['core_references_fraction_first_order'])
X_val_core2 = list(validation_dataframe['core_references_fraction_second_order'])
X_val_noncore1 = list(validation_dataframe['noncore_references_fraction_first_order'])
X_val_noncore2 = list(validation_dataframe['noncore_references_fraction_second_order'])
X_val_num_refs1 = list(validation_dataframe['total_first_order_references'])
X_val_num_refs2 = list(validation_dataframe['total_second_order_references'])
y_val = validation_labels

# %%
def zip_data(text, core1, core2, noncore1, noncore2, num_refs1, num_refs2, y, actual_text):
    X_p_text, X_p_ref, y_p, X_text_actual = [], [], [], []
    for pair in zip(text, core1, core2, noncore1, noncore2, num_refs1, num_refs2, y, actual_text):
        X_p_text.append(Variable(LongTensor(pair[0])).view(1, -1))
        X_p_ref.append(Variable(FloatTensor([pair[1], pair[2], pair[3], pair[4], pair[5], pair[6]])).view(1, -1))
        y_p.append(Variable(LongTensor([pair[7]])).view(1, -1))
        X_text_actual.append(pair[8])
        
    return list(zip(X_p_text, X_p_ref, y_p, X_text_actual))

# %%
training_data = zip_data(X_train, X_train_core1, X_train_core2, X_train_noncore1, 
                         X_train_noncore2, X_train_num_refs1, X_train_num_refs2, 
                         y_train, training_dataframe.text)
validation_data = zip_data(X_val, X_val_core1, X_val_core2, X_val_noncore1, 
                         X_val_noncore2, X_val_num_refs1, X_val_num_refs2, 
                         y_val, validation_dataframe.text)

# %% [markdown]
# ##### Load pre-trained Word Vectors

# %%
import gensim

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
len(model.index2word)
# Out:
# 3000000

# %%
pretrained = []

for key in inspire_data_stoi.keys():
    try:
        pretrained.append(model[inspire_data_stoi[key]])
    except:
        pretrained.append(np.random.randn(300))
        
pretrained_vectors = np.vstack(pretrained)

# %% [markdown]
# ## Train

# %%
EPOCH = 5
BATCH_SIZE = 64
KERNEL_SIZES = [3,4,5,6]
KERNEL_DIM = 200
DROPOUT = 0.2
LR = 0.001
REF_FC_LAYER1_DIM = 200
REF_FC_LAYER2_DIM = 100

# %%
class  CNN_Classifier_MultiHead(nn.Module):
    
    def __init__(self, vocab_size, embedding_dim, output_size, kernel_dim=100, kernel_sizes=(3, 4, 5), dropout=0.5,
                 ref_fc_layer1_dim=200, ref_fc_layer2_dim=100):
        super(CNN_Classifier_MultiHead,self).__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.convs = nn.ModuleList([nn.Conv2d(1, kernel_dim, (K, embedding_dim)) for K in kernel_sizes])
        self.bn_conv = nn.BatchNorm2d(200)

        # FC Layer for the reference fractions
        self.fc_reference_fraction1 = nn.Linear(6, ref_fc_layer1_dim)
        self.bn_fcr1 = nn.BatchNorm1d(ref_fc_layer1_dim)
        self.fc_reference_fraction2 = nn.Linear(ref_fc_layer1_dim, ref_fc_layer2_dim)
        self.bn_fcr2 = nn.BatchNorm1d(ref_fc_layer2_dim)
        
        # kernal_size = (K,D) 
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(len(kernel_sizes) * kernel_dim + ref_fc_layer2_dim, output_size)
    
    
    def init_weights(self, pretrained_word_vectors, is_static=False):
        self.embedding.weight = nn.Parameter(torch.from_numpy(pretrained_word_vectors).float())
        if is_static:
            self.embedding.weight.requires_grad = False


    def forward(self, text_inputs, reference_fraction_inputs, is_training=False):
        text_inputs = self.embedding(text_inputs).unsqueeze(1) # (B,1,T,D)
        text_inputs = [F.relu(self.bn_conv(conv(text_inputs))).squeeze(3) for conv in self.convs] #[(N,Co,W), ...]*len(Ks)
        text_inputs = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in text_inputs] #[(N,Co), ...]*len(Ks)

        concated = torch.cat(text_inputs, dim=1)
        
        reference_fraction_out = self.bn_fcr1(self.fc_reference_fraction1(reference_fraction_inputs))
        reference_fraction_out2 = self.bn_fcr2(self.fc_reference_fraction2(reference_fraction_out))
        super_concatenated = torch.cat((concated, reference_fraction_out2), dim=1)

        if is_training:
            super_concatenated = self.dropout(super_concatenated) # (N,len(Ks)*Co)
        out = self.fc(super_concatenated)
        return F.log_softmax(out,1)

# %%
model = CNN_Classifier_MultiHead(len(inspire_data_itos), 300, len(set(y_train)), KERNEL_DIM, KERNEL_SIZES, dropout=DROPOUT,
                                ref_fc_layer1_dim=REF_FC_LAYER1_DIM, ref_fc_layer2_dim=REF_FC_LAYER2_DIM)
model.init_weights(pretrained_vectors) # initialize embedding matrix using pretrained vectors

if USE_CUDA:
    model = model.cuda()
    
loss_function = nn.CrossEntropyLoss(weight=class_weights)
# optimizer = optim.Adam([
#     {'params': model.embedding.parameters()},
#     {'params': model.convs.parameters()},
#     {'params': model.dropout.parameters()}, 
#     {'params': model.fc.parameters()},
#     {'params': model.bn_conv.parameters()},
#     {'params': model.bn_fcr1.parameters()},
#     {'params': model.bn_fcr2.parameters()},
#     {'params': model.fc_reference_fraction1.parameters(), 'lr': 0.0001},
#     {'params': model.fc_reference_fraction2.parameters(), 'lr': 0.0001}
# ], lr=LR)
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

# %%
print(model)
# Out:
# CNN_Classifier_MultiHead(
#   (embedding): Embedding(60002, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 200, kernel_size=(3, 300), stride=(1, 1))
#     (1): Conv2d(1, 200, kernel_size=(4, 300), stride=(1, 1))
#     (2): Conv2d(1, 200, kernel_size=(5, 300), stride=(1, 1))
#     (3): Conv2d(1, 200, kernel_size=(6, 300), stride=(1, 1))
#   )
#   (bn_conv): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction1): Linear(in_features=6, out_features=200, bias=True)
#   (bn_fcr1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction2): Linear(in_features=200, out_features=100, bias=True)
#   (bn_fcr2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=900, out_features=3, bias=True)
# )

# %%
def train_model(train_data, model, loss_function, epoch):
    '''
    Trains the model for one epoch
    '''
    
    model.train()
    avg_loss = []
    avg_train_acc = []
    
    for i, batch in enumerate(getBatch_MultiHead(BATCH_SIZE, train_data)):
        text_inputs, reference_fraction_inputs, targets, _ = pad_to_batch_MultiHead(batch)
        
        model.zero_grad()
        preds = model(text_inputs, reference_fraction_inputs, True)
        
        loss = loss_function(preds, targets)
        loss.backward()
        
        optimizer.step()
        
        train_acc = (sum(preds.max(1)[1] == targets).item() / BATCH_SIZE) * 100
        
        if i % 100 == 0:
            print('TRAIN [Epoch : {}/{}][Batch: {}] Batch Train Loss: {}, Batch Train Accuracy: {}'.format(epoch, EPOCH, 
                                                                                                i, loss.item(),
                                                                                                train_acc))
    
        avg_loss.append(loss.item())
        avg_train_acc.append(train_acc)
        
    avg_loss = np.mean(avg_loss)
    avg_train_acc = np.mean(avg_train_acc)

    return avg_loss, avg_train_acc

def validate(val_data, model, loss_function, epoch):
    
    model.eval()
    avg_loss = []
    avg_test_acc = []
    
    for i, batch in enumerate(getBatch_MultiHead(BATCH_SIZE, val_data)):
        text_inputs, reference_fraction_inputs, targets, _ = pad_to_batch_MultiHead(batch)
        
        preds = model(text_inputs, reference_fraction_inputs, False)
        
        loss = loss_function(preds, targets)
        
        test_acc = (sum(preds.max(1)[1] == targets).item() / BATCH_SIZE) * 100
        
        if i % 100 == 0:
            print('VAL [Epoch : {}/{}][Batch: {}] Batch Test Loss: {}, Batch Test Accuracy: {}'.format(epoch, EPOCH, 
                                                                                                i, loss.item(),
                                                                                                test_acc))
    
        avg_loss.append(loss.item())
        avg_test_acc.append(test_acc)
        
    avg_loss = np.mean(avg_loss)
    avg_test_acc = np.mean(avg_test_acc)

    return avg_loss, avg_test_acc

# %%
train_loss, train_acc, val_loss, val_acc = [], [], [], []
for epoch in range(EPOCH):
    
    scheduler.step()
    
    print('<<<<<<<<<<<<<TRAINING>>>>>>>>>>>>')
    epoch_train_loss, epoch_train_acc = train_model(training_data, model, loss_function, epoch)
    print('[TRAIN] EPOCH: {}, Loss: {}, Accuracy: {}'.format(epoch, epoch_train_loss, epoch_train_acc))
    train_loss.append(epoch_train_loss)
    train_acc.append(epoch_train_acc)
    
    print('<<<<<<<<<<<<< VALIDATING >>>>>>>>>>>>')
    epoch_val_loss, epoch_val_acc = validate(validation_data, model, loss_function, epoch)
    print('[VAL] EPOCH: {}, Loss: {}, Accuracy: {}'.format(epoch, epoch_val_loss, epoch_val_acc))    
    val_loss.append(epoch_val_loss)
    val_acc.append(epoch_val_acc)
# Out:
# <<<<<<<<<<<<<TRAINING>>>>>>>>>>>>
# TRAIN [Epoch : 0/5][Batch: 0] Batch Train Loss: 1.2773828506469727, Batch Train Accuracy: 43.75
# TRAIN [Epoch : 0/5][Batch: 100] Batch Train Loss: 0.2694782614707947, Batch Train Accuracy: 93.75
# TRAIN [Epoch : 0/5][Batch: 200] Batch Train Loss: 0.42720770835876465, Batch Train Accuracy: 82.8125
# TRAIN [Epoch : 0/5][Batch: 300] Batch Train Loss: 0.421206533908844, Batch Train Accuracy: 75.0
# TRAIN [Epoch : 0/5][Batch: 400] Batch Train Loss: 0.5585194826126099, Batch Train Accuracy: 75.0
# TRAIN [Epoch : 0/5][Batch: 500] Batch Train Loss: 0.25712037086486816, Batch Train Accuracy: 90.625
# TRAIN [Epoch : 0/5][Batch: 600] Batch Train Loss: 0.44909054040908813, Batch Train Accuracy: 82.8125
# TRAIN [Epoch : 0/5][Batch: 700] Batch Train Loss: 0.3109096586704254, Batch Train Accuracy: 87.5
# TRAIN [Epoch : 0/5][Batch: 800] Batch Train Loss: 0.36675965785980225, Batch Train Accuracy: 82.8125
# TRAIN [Epoch : 0/5][Batch: 900] Batch Train Loss: 0.2995890974998474, Batch Train Accuracy: 85.9375
# TRAIN [Epoch : 0/5][Batch: 1000] Batch Train Loss: 0.339368999004364, Batch Train Accuracy: 84.375
# TRAIN [Epoch : 0/5][Batch: 1100] Batch Train Loss: 0.3717832565307617, Batch Train Accuracy: 84.375
# TRAIN [Epoch : 0/5][Batch: 1200] Batch Train Loss: 0.3831727206707001, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 0/5][Batch: 1300] Batch Train Loss: 0.20492404699325562, Batch Train Accuracy: 93.75
# TRAIN [Epoch : 0/5][Batch: 1400] Batch Train Loss: 0.36085984110832214, Batch Train Accuracy: 85.9375
# TRAIN [Epoch : 0/5][Batch: 1500] Batch Train Loss: 0.38434064388275146, Batch Train Accuracy: 87.5
# TRAIN [Epoch : 0/5][Batch: 1600] Batch Train Loss: 0.579230785369873, Batch Train Accuracy: 75.0
# TRAIN [Epoch : 0/5][Batch: 1700] Batch Train Loss: 0.2309093177318573, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 0/5][Batch: 1800] Batch Train Loss: 0.16107764840126038, Batch Train Accuracy: 93.75
# TRAIN [Epoch : 0/5][Batch: 1900] Batch Train Loss: 0.3104340732097626, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 0/5][Batch: 2000] Batch Train Loss: 0.40983566641807556, Batch Train Accuracy: 81.25
# TRAIN [Epoch : 0/5][Batch: 2100] Batch Train Loss: 0.48392021656036377, Batch Train Accuracy: 81.25
# TRAIN [Epoch : 0/5][Batch: 2200] Batch Train Loss: 0.13369116187095642, Batch Train Accuracy: 95.3125
# TRAIN [Epoch : 0/5][Batch: 2300] Batch Train Loss: 0.3077729642391205, Batch Train Accuracy: 92.1875
# [TRAIN] EPOCH: 0, Loss: 0.3602942473103748, Accuracy: 85.07429600171969
# <<<<<<<<<<<<< VALIDATING >>>>>>>>>>>>
# VAL [Epoch : 0/5][Batch: 0] Batch Test Loss: 0.2570250630378723, Batch Test Accuracy: 84.375
# VAL [Epoch : 0/5][Batch: 100] Batch Test Loss: 0.45004814863204956, Batch Test Accuracy: 78.125
# VAL [Epoch : 0/5][Batch: 200] Batch Test Loss: 0.3245413899421692, Batch Test Accuracy: 82.8125
# VAL [Epoch : 1/5][Batch: 400] Batch Test Loss: 0.39227294921875, Batch Test Accuracy: 87.5
# VAL [Epoch : 1/5][Batch: 500] Batch Test Loss: 0.4631879925727844, Batch Test Accuracy: 78.125
# [VAL] EPOCH: 1, Loss: 0.37352759492202725, Accuracy: 82.60577749140893
# <<<<<<<<<<<<<TRAINING>>>>>>>>>>>>
# TRAIN [Epoch : 2/5][Batch: 0] Batch Train Loss: 0.21719379723072052, Batch Train Accuracy: 87.5
# TRAIN [Epoch : 2/5][Batch: 100] Batch Train Loss: 0.281212717294693, Batch Train Accuracy: 93.75
# TRAIN [Epoch : 2/5][Batch: 200] Batch Train Loss: 0.5725198984146118, Batch Train Accuracy: 82.8125
# TRAIN [Epoch : 2/5][Batch: 300] Batch Train Loss: 0.26708540320396423, Batch Train Accuracy: 87.5

# %% [markdown]
# #### Make loss and accuracy plots

# %%
# Accuracy
epochs = range(1, EPOCH + 1)

plt.figure(figsize=(16, 9))
plt.plot(epochs, train_acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.show()

# %%
# Loss

plt.figure(figsize=(16, 9))
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluate on validation set

# %% [markdown]
# accuracy = 0
#
# for test in val_data:
#     pred = model(test[0], test[1], False).max(1)[1]
#     pred = pred.data.tolist()[0]
#     target = test[1].data.tolist()[0][0]
#     if pred == target:
#         accuracy += 1
#
# print(accuracy/len(val_data) * 100)

# %%
if 'Y_VAL' in locals():
    del Y_VAL, Y_VAL_PREDS

actual_text = []
encoded_text = []
ref_fracs = []
labels = []
predicted = []

for data in getBatch_MultiHead(50, validation_data):
    text_inputs, ref_inputs, targets, text_actual = pad_to_batch_MultiHead(data)

    y_val_pred = model(text_inputs, ref_inputs, False)
    preds = y_val_pred.max(1)[1]
    
    if 'Y_VAL' in locals():
        Y_VAL = torch.cat((Y_VAL, targets), 0)
        Y_VAL_PREDS = torch.cat((Y_VAL_PREDS, preds), 0)
    else:
        Y_VAL = targets
        Y_VAL_PREDS = preds
        
    encoded_text.append(text_inputs)
    actual_text.append(text_actual)
    ref_fracs.append(ref_inputs)
    labels.append(targets)
    predicted.append(preds)

# %%
enc_text = [text.cpu().numpy() for text_list in encoded_text for text in text_list]
raw_text = [text for text_list in actual_text for text in text_list[0]]
ref_fractions = [tuple(ref_f.cpu().numpy()) for sublist in ref_fracs for ref_f in sublist]
pd_labels = [l.item() for sublist in labels for l in sublist]
pd_predicted = [p.item() for sublist in predicted for p in sublist]

# %%
from sklearn.metrics import confusion_matrix

# %%
conf_mat = confusion_matrix(pd_labels, pd_predicted, labels = [0, 1, 2])

# %%
# funtion to plot confusion matrices, will be needed later

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
        plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    else:
        print('Confusion matrix, without normalization')
        plt.imshow(cm, interpolation='nearest', cmap=cmap)

    print(cm)
    
    
    plt.title(title)
    plt.colorbar( )
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.figure()
plot_confusion_matrix(conf_mat, ['Rejected', 'Non-Core', 'Core'], normalize=True)
plt.show()
# Out:
# Normalized confusion matrix
# [[0.98537 0.01229 0.00234]
#  [0.09395 0.8106  0.09545]
#  [0.01495 0.06273 0.92231]]

# %%
plt.figure()
plot_confusion_matrix(conf_mat, ['Rejected', 'Non-Core', 'Core'], normalize=False)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8015   100    19]
#  [ 1443 12450  1466]
#  [  205   860 12644]]

# %% [markdown]
# ### Look at the mismatches

# %%
predictions = pd.DataFrame(data={'text': raw_text, 'encoded_text': enc_text, 'ref_fractions': ref_fractions, 'label': pd_labels, 'pred': pd_predicted})

# %%
predictions.to_pickle('inspire_data_with_reference_fractions_and_num_references/predictions_ulmfit_preprocessing.pkl')

# %%
predictions.head()
# Out:
#                                                 text  \
# 0  Transverse Field Perturbation For PIP-II SRF C...
# 1  A framework of Rogers–Ramanujan identities and...
# 2  Robust quantum coherence above the Fermi sea <...
# 3  FIFRELIN – TRIPOLI-4® coupling for Monte Carlo...
# 4  Demonstrating High-precision, Multiband Transi...
#
#                                         encoded_text  \
# 0  [21, 26, 27, 20, 441, 50, 891, 12, 10, 8277, 6...
# 1  [21, 26, 27, 20, 9, 281, 3, 16516, 140, 10982,...
# 2  [21, 26, 27, 20, 1268, 72, 2258, 519, 2, 676, ...
# 3  [21, 26, 27, 20, 10, 46957, 140, 10, 21698, 84...
# 4  [21, 26, 27, 20, 3594, 55, 6, 552, 5, 8043, 58...
#
#                                        ref_fractions  label  pred
# 0  (-1.645081e-05, -0.61458623, -0.10288895, -0.8...      2     1
# 1  (-0.6785068, 0.27651313, -0.62129873, -0.29390...      1     1
# 2  (-0.7825089, -0.84908605, -0.7329562, -0.86312...      0     0
# 3  (-0.7825089, -0.8274399, 1.1047399, 1.133549, ...      1     1
# 4  (-0.7825089, -0.84908605, -0.7329562, -0.86312...      0     0

# %%
pred_rejected_but_core = predictions[(predictions.label == 2) &  (predictions.pred == 0)]

# %%
# %pprint on
print(pred_rejected_but_core.ref_fractions)
# Out:
# Pretty printing has been turned ON
# 28       (-0.54085684, -0.09053008, -0.7329562, -0.7358...
# 1113     (-0.5718379, -0.34658644, -0.7329562, -0.86312...
# 1500     (-0.7825089, -0.84908605, 0.068947576, -0.8631...
# 2186     (-0.24899133, -0.25170103, 0.011668735, -0.137...
# 2231     (-0.70195824, -0.77091944, -0.6680963, -0.8631...
# 2291     (-0.47478718, -0.12021445, -0.23739769, 0.4966...
# 2370     (-0.326055, -0.60356945, -0.36541697, -0.30645...
# 2851     (-0.41734576, 0.08891327, -0.7329562, -0.53785...
# 3488     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 3876     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 4409     (-0.66839546, -0.5432167, -0.36541697, -0.4918...
# 4497     (-0.7825089, -0.30793262, -0.18164735, -0.1750...
# 4730     (-0.4339441, -0.40164292, 1.0312321, 0.4339234...
# 4781     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 5532     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 5613     (-0.46030614, 0.040027313, -0.38703692, -0.555...
# 6362     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 6661     (-0.7825089, -0.16362502, 0.659824, -0.4565380...
# 6831     (-0.53353405, 1.37934, -0.6327182, -0.7503183,...
# 7146     (-0.544359, -0.5548738, 0.41760138, -0.6162950...
# 7271     (-0.6561063, 0.59699625, -0.5972494, -0.117711...
# 7768     (-0.37170038, -0.06544105, -0.7329562, -0.7396...
# 8472     (-0.7825089, -0.84908605, -0.26869613, -0.2267...
# 9781     (-0.52575356, 0.7060181, -0.7329562, -0.542136...
# 9909     (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 10300    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 10310    (-0.7825089, -0.65895104, -0.4809293, -0.73126...
# 11179    (-0.59992737, -0.5402326, 0.14913796, 0.069056...
# 11548    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 11717    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 12002    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 12982    (-0.65413123, 1.2614125, -0.7329562, -0.752241...
# 13105    (-0.5428706, -0.5315581, 0.3145306, 0.14693753...
# 13191    (-0.7825089, -0.84908605, 0.44316933, -0.16611...
# 13546    (-0.7825089, -0.84908605, -0.24290389, 0.76323...
# 13678    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 13884    (-0.5868858, -0.2610865, -0.10288895, 0.156384...
# 14527    (-0.7690177, -0.7645024, 0.04919625, -0.301733...
# 14844    (-0.7825089, -0.72673833, -0.14489342, 1.25821...
# 15617    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 17011    (-0.36116683, 0.95991266, -0.7329562, 0.356645...
# 17306    (-0.2804096, -0.32127613, 0.2226458, 0.0931536...
# 17338    (-0.5477612, -0.33935443, 0.2751514, 0.4686350...
# 17485    (-0.7352896, -0.6362627, -0.580871, -0.6171247...
# 18174    (-0.7011607, -0.7140253, -0.28171992, -0.40684...
# 18844    (-0.5949251, 0.5910188, -0.43086916, -0.633525...
# 18886    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 19299    (-0.53353405, -0.30351502, -0.7329562, -0.6639...
# 19856    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 20775    (-0.6214075, 0.08891327, -0.47351673, 2.389605...
# 21534    (-0.15049577, -0.3643217, -0.39368922, 0.26439...
# 22173    (-0.48907426, -0.4826119, 0.054627866, 0.54386...
# 22661    (-0.4782063, -0.25976712, -0.24290389, -0.0712...
# 22755    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 22827    (-0.7539806, -0.79810786, -0.089762546, 0.0936...
# 23189    (-0.7053618, -0.72929966, 0.012475479, -0.3183...
# 23459    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 23499    (-0.7825089, -0.40833938, -0.10288895, 1.84095...
# 23849    (-0.69121814, 0.44968224, -0.5859405, 0.262816...
# 24164    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 25396    (-0.09782801, -0.2581465, -0.26040575, 0.25906...
# 26146    (-0.07246946, 0.8460935, -0.7329562, -0.098933...
# 26488    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 26988    (-0.23476419, 1.0560056, -0.29190913, -0.76920...
# 27431    (-0.7242382, -0.47027865, 0.017762229, -0.1437...
# 27554    (-0.66839546, 1.1266998, -0.7329562, -0.551697...
# 28069    (-0.53353405, 0.5210805, -0.3320043, -0.531044...
# 29223    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 29374    (-0.44016847, -0.690551, 0.9209703, 0.54562503...
# 30164    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 30530    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 30768    (-0.6058171, -0.06116662, -0.30613643, -0.2776...
# 31333    (-0.7140408, -0.7035344, -0.4021709, -0.484578...
# 32083    (-0.44016847, -3.4942084e-05, -0.31947455, 0.0...
# 32539    (-0.53353405, -0.6425541, -0.3320043, 0.345455...
# 33014    (-0.7825089, -0.84908605, -0.7329562, -0.86312...
# 34545    (-0.21587645, -0.17962687, -0.3527432, -0.0840...
# 36371    (-0.56770706, -0.17041595, -0.7329562, -0.7196...
# 37158    (-0.41025522, -0.28260002, 0.20908609, -0.0833...
# Name: ref_fractions, dtype: object

# %%
enc_word_bag = np.array([token for sentence in pred_rejected_but_core.text for token in sentence.split()])

# %%
v, c = np.unique(enc_word_bag, return_counts=True)

# %%
sdf = pd.DataFrame(data={'values': v, 'counts': c})

# %%
sdf.sort_values('counts', ascending=False)
# Out:
#                       values  counts
# 3228                     the     768
# 2438                      of     556
# 854                        a     320
# 955                      and     247
# 3281                      to     210
# 2003                      in     204
# 2104                      is     154
# 1785                     for     129
# 808                       We     113
# 3226                    that      99
# 2445                      on      92
# 3474                    with      92
# 2735                 quantum      82
# 3451                      we      79
# 242               <ENDTITLE>      79
# 764                      The      71
# 1117                      by      70
# 1058                      be      64
# 998                      are      64
# 1011                      as      60
# 3257                    this      52
# 939                       an      50
# 3466                   which      48
# 504                       In      39
# 1126                     can      38
# 1819                    from      34
# 2959                    show      31
# 1744                   field      29
# 1027                      at      24
# 2111                      it      24
# 931                     also      23
# 3242                  theory      23
# 3030                   space      23
# 2289                   model      22
# 3120                   study      21
# 3250                   these      21
# 1927                     has      21
# 2471                   order      21
# 3055                    spin      20
# 3108               structure      20
# 2272                  method      19
# 2860                 results      19
# 775                     This      19
# 1516                 discuss      19
# 245                        A      18
# 2367                     new      18
# 3139                    such      17
# 3462                   where      17
# 2408                     not      17
# 3081                   state      16
# 3394                   using      16
# 444                 Gaussian      16
# 1850                 general      16
# 2498                    over      15
# 2114                     its      15
# 1192               classical      15
# 923                      all      15
# 3184              symplectic      15
# 568                      Lie      15
# 1823                function      15
# 2205                magnetic      14
# 3225                    than      14
# 3019               solutions      14
# 2631                 present      14
# 2693              properties      14
# 2554                   phase      14
# 970                      any      14
# 1017              associated      14
# 1076                 between      13
# 2468                      or      13
# 1629               equations      13
# 2493                     our      13
# 1607                  energy      13
# 1907                   group      13
# 3168                 surface      13
# 1244                 complex      13
# 1291                consider      13
# 1754                    find      12
# 1763                   first      12
# 1928                    have      12
# 1947                  higher      12
# 2448                     one      12
# 986                 approach      12
# 3387                     use      12
# 2490                   other      12
# 2505                   paper      12
# 2087               invariant      12
# 3455                    well      12
# 1871                geometry      12
# 2276                  metric      12
# 1788                    form      12
# 635                      Our      11
# 1759                  finite      11
# 1457             description      11
# 3086                  states      11
# 3340                     two      11
# 1190                 classes      11
# 3413                  vector      11
# 1173                  charge      11
# 2304                  moduli      11
# 3220                   terms      11
# 2662                 problem      11
# 3025                    some      10
# 2587                   point      10
# 3373               universal      10
# 2523             particular,      10
# 3284             topological      10
# 1302                constant      10
# 911                  algebra      10
# 1814                    free      10
# 1082                  binary      10
# 1086                   black      10
# 2707                 provide      10
# 519                       It      10
# 1093                    both      10
# 1488               different      10
# 1441                 density       9
# 1964                     how       9
# 673                  Quantum       9
# 2129                   known       9
# 1880                    give       9
# 984                    apply       9
# 1444              dependence       9
# 269                       As       9
# 3253                    they       9
# 3016                solution       9
# 1854             generalized       9
# 2664                problems       9
# 3074                standard       9
# 3229                   their       9
# 1552                dynamics       9
# 2248                     may       9
# 3461                    when       9
# 701               Riemannian       9
# 425                      For       9
# 2453                    only       9
# 772                    These       9
# 1570               efficient       9
# 1225           combinatorial       8
# 2076                    into       8
# 1057                   based       8
# 1217           cohomological       8
# 1857               generated       8
# 601                    Monte       8
# 2413               numerical       8
# 1388                 current       8
# 1786                   force       8
# 1150                 certain       8
# 3382                      up       8
# 1881                   given       8
# 2178                   local       8
# 3010                      so       8
# 1490            differential       8
# 1023             assumptions       8
# 2168                    line       8
# 2522              particular       8
# 1584              elementary       8
# 3211             temperature       8
# 2411                  number       8
# 2460               operators       8
# 1658               evolution       8
# 2611               potential       8
# 463                     Hall       8
# 1380                critical       8
# 2710                provides       8
# 1833             fundamental       8
# 3096              stochastic       8
# 3189                 systems       8
# 1867               geometric       8
# 2195                     low       8
# 2227                 mapping       8
# 2234                 massive       8
# 2428                  obtain       8
# 2322                    more       7
# 1116                     but       7
# 1767                   fixed       7
# 3360                   under       7
# 2459                operator       7
# 1113                 bundles       7
# 314                    Carlo       7
# 1625                equation       7
# 1821                    full       7
# 1174                 charged       7
# 2457              operations       7
# 2516                    part       7
# 1954                    hole       7
# 2216                manifold       7
# 1310            construction       7
# 920                algorithm       7
# 531                   Kahler       7
# 1308               construct       7
# 2814            relativistic       7
# 1306             constraints       7
# 2609                possible       7
# 3467                   while       7
# 413                    Field       7
# 682                       RS       7
# 44                       $W$       7
# 3227                   that,       7
# 2273                 methods       7
# 480                    Hodge       7
# 3186                  system       7
# 983                  applied       7
# 2630                presence       7
# 1138                    case       7
# 1694                explicit       7
# 1005              arithmetic       7
# 1768                    flat       7
# 243                        =       6
# 2324                  motion       6
# 780              Topological       6
# 2705                   prove       6
# 472                     Here       6
# 1955                   holes       6
# 1652                    even       6
# 2294                  models       6
# 2979             simulations       6
# 1828               functions       6
# 415                 Finally,       6
# 2223                    many       6
# 2374                   nodal       6
# 3234                    then       6
# 1843                     gap       6
# 699                  Riemann       6
# 3181                symmetry       6
# 1849                   gauge       6
# 2296                 models.       6
# 2847                resource       6
# 2760                   ratio       6
# 1025              asymptotic       6
# 2856                  result       6
# 1747                  fields       6
# 3110              structures       6
# 1749                 fields.       6
# 3034                  space.       6
# 3267                 through       6
# 2287                   mixed       6
# 1520              disordered       6
# 1580           electrostatic       6
# 1436             demonstrate       6
# 2566                physical       6
# 1248               component       6
# 1523                distance       6
# 2640                previous       6
# 214                       2D       6
# 1189                   class       6
# 2170                  linear       6
# 1277             conformally       6
# 3349                    type       6
# 1454               described       6
# 2494                     out       6
# 180                        -       6
# 3443                    wave       6
# 1408                    data       6
# 1423                 defined       6
# 2649               principal       6
# 3423                     via       6
# 2698                 propose       6
# 3261                   three       5
# 985                 applying       5
# 3245                   there       5
# 2972                  simple       5
# 1741                fermions       5
# 1239              compatible       5
# 996                arbitrary       5
# 3260                   those       5
# 1990             implemented       5
# 3007                  smooth       5
# 1446                   depth       5
# 1449                  derive       5
# 1453                describe       5
# 3409             variational       5
# 560                Laplacian       5
# 1566                 effects       5
# 2410                   novel       5
# 1234                 compact       5
# 2519                particle       5
# 2787                 reduced       5
# 3400                   value       5
# 2606                positive       5
# 3388                    used       5
# 917                algebroid       5
# 3213                temporal       5
# 2820                relevant       5
# 375         Donaldson-Thomas       5
# 2808                 related       5
# 912                 algebra,       5
# 3469                   whose       5
# 1422                  define       5
# 1280              conjecture       5
# 947                 analytic       5
# 2930                sequence       5
# 3470                    wide       5
# 362                     Dehn       5
# 1957             homogeneous       5
# 1905                  ground       5
# 1426             deformation       5
# 2836          representation       5
# 1676               existence       5
# 410                    Fermi       5
# 3191                systems.       5
# 1230                  common       5
# 924                    allow       5
# 1471               detection       5
# 626                       On       5
# 779                       To       5
# 1800             formulation       5
# 1358           corresponding       5
# 2310                momentum       5
# 1367                 coupled       5
# 2208         magnetoelectric       5
# 2732            quantization       5
# 1811               framework       5
# 1503             dimensional       5
# 3491                    zero       5
# 2249                    mean       5
# 1077                  beyond       5
# 2291                  model.       5
# 3035                  spaces       5
# 464              Hamiltonian       5
# 2721               quadratic       5
# 2154                    less       5
# 2207           magnetization       5
# 2016                 induced       5
# 1062                    been       5
# 1862                 generic       5
# 3448              wavepacket       5
# 2243                  matrix       5
# 1049                    band       5
# 1216                coherent       5
# 769                   Theory       5
# 2132                   large       5
# 1942                    high       5
# 2323                    most       5
# 1506                  direct       5
# 3425                  viewed       5
# 2347                 natural       5
# 2150                 length,       5
# 490               Hypothesis       4
# 470               Heisenberg       4
# 1393                  curves       4
# 2946                   sheaf       4
# 2335                multiple       4
# 2232                    mass       4
# 1545                    dual       4
# 485                     Hove       4
# 3441                     was       4
# 915                 algebras       4
# 897                   admits       4
# 395                Euclidean       4
# 2464                 optical       4
# 914                algebraic       4
# 1825              functional       4
# 1526                distinct       4
# 2560              phenomenon       4
# 798                    Using       4
# 59                $\Phi_4^4$       4
# 3435                  vortex       4
# 1557                    each       4
# 3171                surfaces       4
# 2541             performance       4
# 3420                  vertex       4
# 860                    about       4
# 1962                homotopy       4
# 2146                   leads       4
# 1743                fidelity       4
# 2244                  matter       4
# 3417                 version       4
# 1565               effective       4
# 3111             structures.       4
# 2237                material       4
# 871                  account       4
# 2834                  report       4
# 2844                requires       4
# 1531                      do       4
# 1400                   cycle       4
# 702                    Rings       4
# 882                   action       4
# 2149                  length       4
# 2454                    open       4
# 2838        representations.       4
# 1351             corrections       4
# 2093             investigate       4
# 527                Josephson       4
# 2550             persistence       4
# 1671             excitations       4
# 2801                  region       4
# 2166                   limit       4
# 2180                 locally       4
# 2733                quantize       4
# 1065                behavior       4
# 3285           topologically       4
# 1663                 examine       4
# 2502                    pair       4
# 2503                 pairing       4
# 2658             probability       4
# 1295              considered       4
# 2049              integrable       4
# 300                       By       4
# 2752                  random       4
# 3274          time-dependent       4
# 187                        1       4
# 1679               expansion       4
# 3270                    time       4
# 312               Calabi-Yau       4
# 1210                    code       4
# 2429                obtained       4
# 1197                   clean       4
# 2188                    long       4
# 1135                 capping       4
# 2286                  mirror       4
# 2699                proposed       4
# 1128               canonical       4
# 1144                category       4
# 604                Moreover,       4
# 2290                  model,       4
# 1122            calculations       4
# 1119               calculate       4
# 1159                  change       4
# 1868             geometrical       4
# 3336                   twist       4
# 1097                boundary       4
# 1882                   gives       4
# 3040                 spatial       4
# 2512              parameters       4
# 2326                 motives       4
# 960                  angular       4
# 2444                   often       4
# 2622                 predict       4
# 2059             interacting       4
# 2225                     map       4
# 1455               describes       4
# 1708                  extend       4
# 946                 analysis       4
# 1710               extension       4
# 1283              connection       4
# 1713                external       4
# 3385                      us       4
# 2061            interactions       4
# 961              anisotropic       4
# 1836                 further       4
# 3090             statistical       4
# 1585                elements       4
# 2781                  recent       4
# 166                      (or       4
# 664                     Prym       4
# 927                   allows       4
# 3005                   small       4
# 929                    along       4
# 178                        ,       4
# 175            )-dimensional       4
# 1689            experimental       4
# 2983                   since       3
# 1497               diffusive       3
# 3044                specific       3
# 1486                diagrams       3
# 609                     Msun       3
# 1831              functions.       3
# 2943                 several       3
# 752                  Systems       3
# 2469                 orbital       3
# 2939                    sets       3
# 2987             singularity       3
# 1496               diffusion       3
# 748                     Such       3
# 1456              describing       3
# 1808              fractional       3
# 1483               developed       3
# 1478               determine       3
# 1534                  domain       3
# 1853          generalization       3
# 2506                  paper,       3
# 3012                software       3
# 1469                detected       3
# 666                      QCR       3
# 2521               particles       3
# 700            Riemann-Theta       3
# 1538                  doping       3
# 1858               generates       3
# 710                  SL(2,C)       3
# 1482                 develop       3
# 627                     Open       3
# 2970                 similar       3
# 1837             furthermore       3
# 2964                   shown       3
# 1539                  double       3
# 1528            distribution       3
# 1479              determined       3
# 1824               function.       3
# 2952                   short       3
# 2317               monopolar       3
# 1855               generally       3
# 1139                   case,       3
# 2927                   sense       3
# 1792               formation       3
# 1054                    base       3
# 1664                 example       3
# 2750                  radial       3
# 2753                   range       3
# 2650               principle       3
# ...                      ...     ...
# 2050                integral       1
# 2051               integral.       1
# 2052             integrality       1
# 2054              integrates       1
# 2030                injected       1
# 2029                 initial       1
# 2028       information-based       1
# 2027            information,       1
# 1999                 imposed       1
# 2000              impossible       1
# 2002             improvement       1
# 2005               included.       1
# 2008          incompressible       1
# 2009              incorrect.       1
# 2010                increase       1
# 2012               increment       1
# 2014                indicate       1
# 2015       indistinguishable       1
# 2017                 induces       1
# 2018              inequality       1
# 2019             inequality,       1
# 2020                inertial       1
# 2021              inevitable       1
# 2023            inflationary       1
# 2025              influenced       1
# 2055             integrating       1
# 2057               intensity       1
# 1994                 implied       1
# 2112                     it.       1
# 2097          investigations       1
# 2098              investment       1
# 2099              involutive       1
# 2100                 involve       1
# 2101                involves       1
# 2105                     is,       1
# 2109               isotropic       1
# 2110                   issue       1
# 2113               iterative       1
# 2058                interact       1
# 2117               junction.       1
# 2118               junctions       1
# 2119                     k)$       1
# 2120                     key       1
# 2121                      kg       1
# 2122                     kg,       1
# 2123                   kicks       1
# 2124                   kind,       1
# 2096           investigation       1
# 2095           investigating       1
# 2091                 inverse       1
# 2090                invasive       1
# 2062           interactions,       1
# 2064          interconnected       1
# 2066              interfaces       1
# 2067            interference       1
# 2068                internal       1
# 2069               interplay       1
# 2070               interpret       1
# 2071          interpretation       1
# 2072         interpretation.       1
# 2074            interpreter,       1
# 2077            intractable.       1
# 2078              intriguing       1
# 2080           intrinsically       1
# 2081             intrinsics.       1
# 2083             introduced.       1
# 2086               intuitive       1
# 2089             invariants.       1
# 1996                   imply       1
# 1992                implicit       1
# 1848                   gates       1
# 1906            ground-based       1
# 1893               googol-th       1
# 1894                governed       1
# 1897               gradient-       1
# 1326               contracts       1
# 1328                 control       1
# 1329                control.       1
# 1331             controller,       1
# 1333            controllers,       1
# 1334            controllers.       1
# 1335           controversial       1
# 1337             convergence       1
# 1338            convergence.       1
# 1339              coordinate       1
# 1340             coordinate.       1
# 1341             coordinates       1
# 1342           coordinates};       1
# 1343                  copies       1
# 3506                   ε=4−d       1
#
# [3507 rows x 2 columns]

# %%
plt.figure(figsize=(16, 9))
plt.subplot(311)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,0])
plt.subplot(312)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,1])
plt.subplot(313)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,2])

# %%
plt.figure(figsize=(16, 9))
plt.subplot(611)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,0])
plt.subplot(612)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,1])
plt.subplot(613)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,2])
plt.subplot(614)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,3])
plt.subplot(615)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,4])
plt.subplot(616)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,5])

# %%
model
# Out:
# CNN_Classifier_MultiHead(
#   (embedding): Embedding(282887, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 200, kernel_size=(3, 300), stride=(1, 1))
#     (1): Conv2d(1, 200, kernel_size=(4, 300), stride=(1, 1))
#     (2): Conv2d(1, 200, kernel_size=(5, 300), stride=(1, 1))
#     (3): Conv2d(1, 200, kernel_size=(6, 300), stride=(1, 1))
#   )
#   (bn_conv): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction1): Linear(in_features=6, out_features=200, bias=True)
#   (bn_fcr1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction2): Linear(in_features=200, out_features=100, bias=True)
#   (bn_fcr2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=900, out_features=3, bias=True)
# )

# %%
(
    (model.fc.weight.cpu().detach().numpy().T[:,0].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,0].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,0].mean()
    ),
    (model.fc.weight.cpu().detach().numpy().T[:,1].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,1].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,1].mean()
    ),
    (model.fc.weight.cpu().detach().numpy().T[:,2].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,2].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,2].mean()
    )
)
# Out:
# ((-0.004086509, -0.0032845945, -0.010501824),
#  (0.0001526185, -0.0003817659, 0.0044276956),
#  (0.00088355056, 3.0283667e-05, 0.0077096857))

# %%
plt.figure(figsize=(16, 9))
plt.imshow(model.fc.weight.cpu().detach().numpy(), aspect='auto')

# %%
# Out:
# CNN_Classifier_MultiHead(
#   (embedding): Embedding(282887, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 200, kernel_size=(3, 300), stride=(1, 1))
#     (1): Conv2d(1, 200, kernel_size=(4, 300), stride=(1, 1))
#     (2): Conv2d(1, 200, kernel_size=(5, 300), stride=(1, 1))
#     (3): Conv2d(1, 200, kernel_size=(6, 300), stride=(1, 1))
#   )
#   (fc_reference_fraction): Linear(in_features=4, out_features=200, bias=True)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=1000, out_features=3, bias=True)
# )
