# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import nltk
import random
import numpy as np
from collections import Counter, OrderedDict
import nltk
import re
from copy import deepcopy
flatten = lambda l: [item for sublist in l for item in sublist]

import matplotlib.pyplot as plt
import itertools
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split

#random.seed(1024)
# %matplotlib inline

pd.options.display.max_rows=1000

# %%
USE_CUDA = torch.cuda.is_available()
gpus = [0]
torch.cuda.set_device(gpus[0])

FloatTensor = torch.cuda.FloatTensor if USE_CUDA else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if USE_CUDA else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if USE_CUDA else torch.ByteTensor

# %%
def getBatch_MultiHead(batch_size, train_data):
    random.shuffle(train_data)
    sindex = 0
    eindex = batch_size
    while eindex < len(train_data):
        batch = train_data[sindex: eindex]
        temp = eindex
        eindex = eindex + batch_size
        sindex = temp
        yield batch
    
    if eindex >= len(train_data):
        batch = train_data[sindex:]
        yield batch

# %%
def pad_to_batch_MultiHead(batch):
    x_text, x_ref_, y, x_text_actual = zip(*batch)
    x_ref = [Variable(FloatTensor(x)).view(1,-1) for x in x_ref_]
    max_x_text = max([s.size(1) for s in x_text])
    x_p_text = []
    x_p_text_actual = []
    for i in range(len(batch)):
        if x_text[i].size(1) < max_x_text:
            x_p_text.append(torch.cat([x_text[i], Variable(LongTensor([word2index['<PAD>']] * (max_x_text - x_text[i].size(1)))).view(1, -1)], 1))
        else:
            x_p_text.append(x_text[i])
        x_p_text_actual.append(x_text_actual)
    return torch.cat(x_p_text), torch.cat(x_ref), torch.cat(y).view(-1), x_p_text_actual

# %%
def prepare_sequence(seq, to_index):
    idxs = list(map(lambda w: to_index[w] if to_index.get(w) is not None else to_index["<UNK>"], seq))
    return Variable(LongTensor(idxs))

# %% [markdown]
# ## Data Loading and Pre-processing

# %%
train_data = pd.read_pickle('inspire_data_with_reference_fractions_and_num_references/inspire_data_augmented_train_corrected.df')
test_data = pd.read_pickle('inspire_data_with_reference_fractions_and_num_references/inspire_data_augmented_test_corrected.df')

# %%
means = train_data.iloc[:,:-2].mean().values
stds = train_data.iloc[:,:-2].std().values

train_data.iloc[:,:-2] = (train_data.iloc[:,:-2] - means) / stds
test_data.iloc[:,:-2] = (test_data.iloc[:,:-2] - means) / stds

# %%
X_train = list(train_data['text'])
X_train_core1 = list(train_data['core_references_fraction_first_order'])
X_train_core2 = list(train_data['core_references_fraction_second_order'])
X_train_noncore1 = list(train_data['noncore_references_fraction_first_order'])
X_train_noncore2 = list(train_data['noncore_references_fraction_second_order'])
X_train_num_refs1 = list(train_data['total_first_order_references'])
X_train_num_refs2 = list(train_data['total_second_order_references'])
y_train = list(train_data['labels'])

# %%
X_test = list(test_data['text'])
X_test_core1 = list(test_data['core_references_fraction_first_order'])
X_test_core2 = list(test_data['core_references_fraction_second_order'])
X_test_noncore1 = list(test_data['noncore_references_fraction_first_order'])
X_test_noncore2 = list(test_data['noncore_references_fraction_second_order'])
X_test_num_refs1 = list(test_data['total_first_order_references'])
X_test_num_refs2 = list(test_data['total_second_order_references'])
y_test = list(test_data['labels'])

# %%
# Get the class weights
rejected_count = y_train.count(0)
noncore_count = y_train.count(1)
core_count = y_train.count(2)

total_count = len(y_train)

inverse_rejected_fraction = total_count / rejected_count
inverse_noncore_fraction = total_count / noncore_count
inverse_core_fraction = total_count / core_count 

sum_fractions = inverse_rejected_fraction + inverse_noncore_fraction + inverse_core_fraction

# Specify the class weights (for the loss function specified later)
class_weights = torch.cuda.FloatTensor((inverse_rejected_fraction/sum_fractions,
                                        inverse_noncore_fraction/sum_fractions,
                                        inverse_core_fraction/sum_fractions))

# %%
class_weights = class_weights / class_weights[1]
print(class_weights)
# Out:
# tensor([1.8749, 1.0000, 1.1123], device='cuda:0')

# %% [markdown]
# ##### Lowercase all text

# %%
# Lowercase the entire text corpora
X_train = [x.lower() for x in X_train]
X_test = [x.lower() for x in X_test]

# %% [markdown]
# ##### Remove punctuation

# %%
punc_to_remove = str('!"%&\'()*+,./:;<=>?@[\\]^_`{|}~')
for i, x in enumerate(X_train):
    X_train[i] = ' '.join(word.strip(punc_to_remove) for word in x.split())
for i, x in enumerate(X_test):
    X_test[i] = ' '.join(word.strip(punc_to_remove) for word in x.split())

# %% [markdown]
# ##### Num Masking

# %%
for i, x in enumerate(X_train):
    X_train[i] = re.sub('\d+', '<NUM>', x)
for i, x in enumerate(X_test):
    X_test[i] = re.sub('\d+', '<NUM>', x)

# %% [markdown]
# ##### Replace Latex Equations

# %%
for i, _ in enumerate(X_train):
    f = re.search(r"(.+(?P<name>\$.+\$).+)+", X_train[i])
    while f is not None:
        X_train[i] = re.sub(re.escape(f.group('name')), '<FORMULA>', X_train[i])
        f = re.search(r"(.+(?P<name>\$.+\$).+)+", X_train[i])
for i, _ in enumerate(X_test):
    f = re.search(r"(.+(?P<name>\$.+\$).+)+", X_test[i])
    while f is not None:
        X_test[i] = re.sub(re.escape(f.group('name')), '<FORMULA>', X_test[i])
        f = re.search(r"(.+(?P<name>\$.+\$).+)+", X_test[i])

# %% [markdown]
# ##### Tokenize the text

# %%
X_train = [nltk.word_tokenize(x) for x in X_train]
X_test = [nltk.word_tokenize(x) for x in X_test]

# %% [markdown]
# ##### Lemmatize the text

# %%
wordnet_lemmatizer = nltk.stem.WordNetLemmatizer()
X_train = [[wordnet_lemmatizer.lemmatize(word) for word in x] for x in X_train]
X_test = [[wordnet_lemmatizer.lemmatize(word) for word in x] for x in X_test]

# %% [markdown]
# ##### Build vocabulary

# %%
vocab = list(set(flatten(X_train)))
print(len(vocab))
# Out:
# 245674

# %%
print(len(set(y_train))) # Number of classes
# Out:
# 3

# %%
word2index={'<PAD>': 0, '<UNK>': 1}

for vo in vocab:
    if word2index.get(vo) is None:
        word2index[vo] = len(word2index)
        
index2word = {v:k for k, v in word2index.items()}

target2index = {}

for cl in set(y_train):
    if target2index.get(cl) is None:
        target2index[cl] = len(target2index)

index2target = {v:k for k, v in target2index.items()}

# %%
pickle.dump(word2index, open('inspire_data_with_reference_fractions_and_num_references/word2index.pkl', 'wb'))
pickle.dump(target2index, open('inspire_data_with_reference_fractions_and_num_references/target2index.pkl', 'wb'))
pickle.dump(X_train, open('inspire_data_with_reference_fractions_and_num_references/X_train.pkl', 'wb'))
pickle.dump(X_test, open('inspire_data_with_reference_fractions_and_num_references/X_test.pkl', 'wb'))

# %%
word2index = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/word2index.pkl', 'rb'))
target2index = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/target2index.pkl', 'rb'))
X_train = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/X_train.pkl', 'rb'))
X_test = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/X_test.pkl', 'rb'))

# %%
def zip_data(text, core1, core2, noncore1, noncore2, num_refs1, num_refs2, y, actual_text):
    X_p_text, X_p_ref, y_p, X_text_actual = [], [], [], []
    for pair in zip(text, core1, core2, noncore1, noncore2, num_refs1, num_refs2, y, actual_text):
        X_p_text.append(prepare_sequence(pair[0], word2index).view(1, -1))
        X_p_ref.append(np.array([pair[1], pair[2], pair[3], pair[4], pair[5], pair[6]]))
        y_p.append(Variable(LongTensor([target2index[pair[7]]])).view(1, -1))
        X_text_actual.append(pair[8])
        
    return list(zip(X_p_text, X_p_ref, y_p, X_text_actual))

# %%
training_data = zip_data(X_train, X_train_core1, X_train_core2, X_train_noncore1, 
                         X_train_noncore2, X_train_num_refs1, X_train_num_refs2, 
                         y_train, train_data.text)
testing_data = zip_data(X_test, X_test_core1, X_test_core2, X_test_noncore1, 
                         X_test_noncore2, X_test_num_refs1, X_test_num_refs2, 
                         y_test, test_data.text)

# %% [raw]
# pickle.dump(word2index, open('inspire_data_with_reference_fractions_and_num_references/word2index.pkl', 'wb'))
# pickle.dump(target2index, open('inspire_data_with_reference_fractions_and_num_references/target2index.pkl', 'wb'))
# pickle.dump(training_data, open('inspire_data_with_reference_fractions_and_num_references/processed_train_data.pkl', 'wb'))
# pickle.dump(testing_data, open('inspire_data_with_reference_fractions_and_num_references/processed_test_data.pkl', 'wb'))

# %% [raw]
# word2index = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/word2index.pkl', 'rb'))
# target2index = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/target2index.pkl', 'rb'))
# training_data = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/processed_train_data.pkl', 'rb'))
# testing_data = pickle.load(open('inspire_data_with_reference_fractions_and_num_references/processed_test_data.pkl', 'rb'))
# class_weights = FloatTensor((1.8798, 1.0000, 1.1185))

# %% [markdown]
# ##### Load pre-trained Word Vectors

# %%
import gensim

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
len(model.index2word)
# Out:
# 3000000

# %%
y_list, n_list = [], []
for key in word2index.keys():
    try:
        model.get_vector(key)
        y_list.append(key)
    except:
        n_list.append(key)
(len(y_list), len(n_list))

# %%
pretrained = []

for key in word2index.keys():
    try:
        pretrained.append(model.get_vector([word2index[key]]))
    except:
        pretrained.append(np.random.randn(300))
        
pretrained_vectors = np.vstack(pretrained)

# %% [markdown]
# ## Train

# %%
EPOCH = 2
BATCH_SIZE = 64
KERNEL_SIZES = [3,4,5,6]
KERNEL_DIM = 200
DROPOUT = 0.2
LR = 0.001
REF_FC_LAYER1_DIM = 200
REF_FC_LAYER2_DIM = 100

# %%
class  CNN_Classifier_MultiHead(nn.Module):
    
    def __init__(self, vocab_size, embedding_dim, output_size, kernel_dim=100, kernel_sizes=(3, 4, 5), dropout=0.5,
                 ref_fc_layer1_dim=200, ref_fc_layer2_dim=100):
        super(CNN_Classifier_MultiHead,self).__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.convs = nn.ModuleList([nn.Conv2d(1, kernel_dim, (K, embedding_dim)) for K in kernel_sizes])
        self.bn_conv = nn.BatchNorm2d(200)

        # FC Layer for the reference fractions
        self.fc_reference_fraction1 = nn.Linear(6, ref_fc_layer1_dim)
        self.bn_fcr1 = nn.BatchNorm1d(ref_fc_layer1_dim)
        self.fc_reference_fraction2 = nn.Linear(ref_fc_layer1_dim, ref_fc_layer2_dim)
        self.bn_fcr2 = nn.BatchNorm1d(ref_fc_layer2_dim)
        
        # kernal_size = (K,D) 
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(len(kernel_sizes) * kernel_dim + ref_fc_layer2_dim, output_size)
    
    
    def init_weights(self, pretrained_word_vectors, is_static=False):
        self.embedding.weight = nn.Parameter(torch.from_numpy(pretrained_word_vectors).float())
        if is_static:
            self.embedding.weight.requires_grad = False


    def forward(self, text_inputs, reference_fraction_inputs, is_training=False):
        text_inputs = self.embedding(text_inputs).unsqueeze(1) # (B,1,T,D)
        text_inputs = [F.relu(self.bn_conv(conv(text_inputs))).squeeze(3) for conv in self.convs] #[(N,Co,W), ...]*len(Ks)
        text_inputs = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in text_inputs] #[(N,Co), ...]*len(Ks)

        concated = torch.cat(text_inputs, dim=1)
        
        reference_fraction_out = self.bn_fcr1(self.fc_reference_fraction1(reference_fraction_inputs))
        reference_fraction_out2 = self.bn_fcr2(self.fc_reference_fraction2(reference_fraction_out))
        super_concatenated = torch.cat((concated, reference_fraction_out2), dim=1)

        if is_training:
            super_concatenated = self.dropout(super_concatenated) # (N,len(Ks)*Co)
        out = self.fc(super_concatenated)
        return F.log_softmax(out,1)

# %%
model = CNN_Classifier_MultiHead(len(word2index), 300, len(target2index), KERNEL_DIM, KERNEL_SIZES, dropout=DROPOUT,
                                ref_fc_layer1_dim=REF_FC_LAYER1_DIM, ref_fc_layer2_dim=REF_FC_LAYER2_DIM)
model.init_weights(pretrained_vectors) # initialize embedding matrix using pretrained vectors

if USE_CUDA:
    model = model.cuda()
    
loss_function = nn.CrossEntropyLoss(weight=class_weights)
# optimizer = optim.Adam([
#     {'params': model.embedding.parameters()},
#     {'params': model.convs.parameters()},
#     {'params': model.dropout.parameters()}, 
#     {'params': model.fc.parameters()},
#     {'params': model.bn_conv.parameters()},
#     {'params': model.bn_fcr1.parameters()},
#     {'params': model.bn_fcr2.parameters()},
#     {'params': model.fc_reference_fraction1.parameters(), 'lr': 0.0001},
#     {'params': model.fc_reference_fraction2.parameters(), 'lr': 0.0001}
# ], lr=LR)
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

# %%
print(model)
# Out:
# CNN_Classifier_MultiHead(
#   (embedding): Embedding(245676, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 200, kernel_size=(3, 300), stride=(1, 1))
#     (1): Conv2d(1, 200, kernel_size=(4, 300), stride=(1, 1))
#     (2): Conv2d(1, 200, kernel_size=(5, 300), stride=(1, 1))
#     (3): Conv2d(1, 200, kernel_size=(6, 300), stride=(1, 1))
#   )
#   (bn_conv): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction1): Linear(in_features=6, out_features=200, bias=True)
#   (bn_fcr1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_reference_fraction2): Linear(in_features=200, out_features=100, bias=True)
#   (bn_fcr2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=900, out_features=3, bias=True)
# )

# %%
def train_model(train_data, model, loss_function, epoch):
    '''
    Trains the model for one epoch
    '''
    
    model.train()
    avg_loss = []
    avg_train_acc = []
    
    for i, batch in enumerate(getBatch_MultiHead(BATCH_SIZE, train_data)):
        text_inputs, reference_fraction_inputs, targets, _ = pad_to_batch_MultiHead(batch)
        
        model.zero_grad()
        preds = model(text_inputs, reference_fraction_inputs, True)
        
        loss = loss_function(preds, targets)
        loss.backward()
        
        optimizer.step()
        
        train_acc = (sum(preds.max(1)[1] == targets).item() / BATCH_SIZE) * 100
        
        if i % 100 == 0:
            print('TRAIN [Epoch : {}/{}][Batch: {}] Batch Train Loss: {}, Batch Train Accuracy: {}'.format(epoch, EPOCH, 
                                                                                                i, loss.item(),
                                                                                                train_acc))
    
        avg_loss.append(loss.item())
        avg_train_acc.append(train_acc)
        
    avg_loss = np.mean(avg_loss)
    avg_train_acc = np.mean(avg_train_acc)

    return avg_loss, avg_train_acc

def validate(val_data, model, loss_function, epoch):
    
    model.eval()
    avg_loss = []
    avg_test_acc = []
    
    for i, batch in enumerate(getBatch_MultiHead(BATCH_SIZE, val_data)):
        text_inputs, reference_fraction_inputs, targets, _ = pad_to_batch_MultiHead(batch)
        
        preds = model(text_inputs, reference_fraction_inputs, False)
        
        loss = loss_function(preds, targets)
        
        test_acc = (sum(preds.max(1)[1] == targets).item() / BATCH_SIZE) * 100
        
        if i % 100 == 0:
            print('VAL [Epoch : {}/{}][Batch: {}] Batch Test Loss: {}, Batch Test Accuracy: {}'.format(epoch, EPOCH, 
                                                                                                i, loss.item(),
                                                                                                test_acc))
    
        avg_loss.append(loss.item())
        avg_test_acc.append(test_acc)
        
    avg_loss = np.mean(avg_loss)
    avg_test_acc = np.mean(avg_test_acc)

    return avg_loss, avg_test_acc

# %%
train_loss, train_acc, val_loss, val_acc = [], [], [], []
for epoch in range(EPOCH):
    
    scheduler.step()
    
    print('<<<<<<<<<<<<<TRAINING>>>>>>>>>>>>')
    epoch_train_loss, epoch_train_acc = train_model(training_data, model, loss_function, epoch)
    print('[TRAIN] EPOCH: {}, Loss: {}, Accuracy: {}'.format(epoch, epoch_train_loss, epoch_train_acc))
    train_loss.append(epoch_train_loss)
    train_acc.append(epoch_train_acc)
    
    print('<<<<<<<<<<<<< VALIDATING >>>>>>>>>>>>')
    epoch_val_loss, epoch_val_acc = validate(testing_data, model, loss_function, epoch)
    print('[VAL] EPOCH: {}, Loss: {}, Accuracy: {}'.format(epoch, epoch_val_loss, epoch_val_acc))    
    val_loss.append(epoch_val_loss)
    val_acc.append(epoch_val_acc)
# Out:
# <<<<<<<<<<<<<TRAINING>>>>>>>>>>>>
Batch Train Accuracy: 84.375
# TRAIN [Epoch : 1/2][Batch: 2100] Batch Train Loss: 0.19371581077575684, Batch Train Accuracy: 92.1875
# TRAIN [Epoch : 1/2][Batch: 2200] Batch Train Loss: 0.28900274634361267, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 1/2][Batch: 2300] Batch Train Loss: 0.24614638090133667, Batch Train Accuracy: 87.5
# TRAIN [Epoch : 1/2][Batch: 2400] Batch Train Loss: 0.21146182715892792, Batch Train Accuracy: 92.1875
# TRAIN [Epoch : 1/2][Batch: 2500] Batch Train Loss: 0.26284876465797424, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 1/2][Batch: 2600] Batch Train Loss: 0.25018858909606934, Batch Train Accuracy: 90.625
# TRAIN [Epoch : 1/2][Batch: 2700] Batch Train Loss: 0.3124156892299652, Batch Train Accuracy: 85.9375
# TRAIN [Epoch : 1/2][Batch: 2800] Batch Train Loss: 0.2399132400751114, Batch Train Accuracy: 89.0625
# TRAIN [Epoch : 1/2][Batch: 2900] Batch Train Loss: 0.24557283520698547, Batch Train Accuracy: 92.1875
# TRAIN [Epoch : 1/2][Batch: 3000] Batch Train Loss: 0.1631486862897873, Batch Train Accuracy: 93.75
# TRAIN [Epoch : 1/2][Batch: 3100] Batch Train Loss: 0.22118477523326874, Batch Train Accuracy: 95.3125
# TRAIN [Epoch : 1/2][Batch: 3200] Batch Train Loss: 0.37371349334716797, Batch Train Accuracy: 87.5
# TRAIN [Epoch : 1/2][Batch: 3300] Batch Train Loss: 0.20335732400417328, Batch Train Accuracy: 92.1875
# TRAIN [Epoch : 1/2][Batch: 3400] Batch Train Loss: 0.41283971071243286, Batch Train Accuracy: 85.9375
# [TRAIN] EPOCH: 1, Loss: 0.25221226558755705, Accuracy: 89.3715954701835
# <<<<<<<<<<<<< VALIDATING >>>>>>>>>>>>
# VAL [Epoch : 1/2][Batch: 0] Batch Test Loss: 0.3451356291770935, Batch Test Accuracy: 81.25
# VAL [Epoch : 1/2][Batch: 100] Batch Test Loss: 0.26908424496650696, Batch Test Accuracy: 89.0625
# VAL [Epoch : 1/2][Batch: 200] Batch Test Loss: 0.31672176718711853, Batch Test Accuracy: 89.0625
# VAL [Epoch : 1/2][Batch: 300] Batch Test Loss: 0.35423457622528076, Batch Test Accuracy: 84.375
# VAL [Epoch : 1/2][Batch: 400] Batch Test Loss: 0.2064998596906662, Batch Test Accuracy: 90.625
# VAL [Epoch : 1/2][Batch: 500] Batch Test Loss: 0.19309790432453156, Batch Test Accuracy: 92.1875
# VAL [Epoch : 1/2][Batch: 600] Batch Test Loss: 0.2323930561542511, Batch Test Accuracy: 93.75
# VAL [Epoch : 1/2][Batch: 700] Batch Test Loss: 0.2929430305957794, Batch Test Accuracy: 85.9375
# VAL [Epoch : 1/2][Batch: 800] Batch Test Loss: 0.35956263542175293, Batch Test Accuracy: 82.8125
# [VAL] EPOCH: 1, Loss: 0.28058172875177967, Accuracy: 87.94617259174312

# %% [markdown]
# #### Make loss and accuracy plots

# %%
# Accuracy
epochs = range(1, EPOCH + 1)

plt.figure(figsize=(16, 9))
plt.plot(epochs, train_acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.show()

# %%
# Loss

plt.figure(figsize=(16, 9))
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluate on validation set

# %% [markdown]
# accuracy = 0
#
# for test in val_data:
#     pred = model(test[0], test[1], False).max(1)[1]
#     pred = pred.data.tolist()[0]
#     target = test[1].data.tolist()[0][0]
#     if pred == target:
#         accuracy += 1
#
# print(accuracy/len(val_data) * 100)

# %%
if 'Y_VAL' in locals():
    del Y_VAL, Y_VAL_PREDS

encoded_text = []
actual_text = []
ref_fracs = []
labels = []
predicted = []

for data in getBatch_MultiHead(50, testing_data):
    text_inputs, ref_inputs, targets, text_actual = pad_to_batch_MultiHead(data)

    y_val_pred = model(text_inputs, ref_inputs, False)
    preds = y_val_pred.max(1)[1]
    
    if 'Y_VAL' in locals():
        Y_VAL = torch.cat((Y_VAL, targets), 0)
        Y_VAL_PREDS = torch.cat((Y_VAL_PREDS, preds), 0)
    else:
        Y_VAL = targets
        Y_VAL_PREDS = preds
    
    encoded_text.append(text_inputs)
    actual_text.append(text_actual)
    ref_fracs.append(ref_inputs)
    labels.append(targets)
    predicted.append(preds)

# %%
enc_text = [text.cpu().numpy() for text_list in encoded_text for text in text_list]
raw_text = [text for text_list in actual_text for text in text_list[0]]
ref_fractions = [tuple(ref_f.cpu().numpy()) for sublist in ref_fracs for ref_f in sublist]
pd_labels = [l.item() for sublist in labels for l in sublist]
pd_predicted = [p.item() for sublist in predicted for p in sublist]

# %%
from sklearn.metrics import confusion_matrix

# %%
conf_mat = confusion_matrix(pd_labels, pd_predicted, labels = [0, 1, 2])

# %%
# funtion to plot confusion matrices, will be needed later

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
        plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    else:
        print('Confusion matrix, without normalization')
        plt.imshow(cm, interpolation='nearest', cmap=cmap)

    print(cm)
    
    
    plt.title(title)
    plt.colorbar( )
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.figure()
plot_confusion_matrix(conf_mat, ['Rejected', 'Non-Core', 'Core'], normalize=True)
plt.show()
# Out:
# Normalized confusion matrix
# [[0.97768931 0.01741727 0.00489342]
#  [0.09251501 0.79695936 0.11052563]
#  [0.01956976 0.06531346 0.91511679]]

# %%
plt.figure()
plot_confusion_matrix(conf_mat, ['Rejected', 'Non-Core', 'Core'], normalize=False)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[11788   210    59]
#  [ 2142 18452  2559]
#  [  403  1345 18845]]

# %% [markdown]
# ### Look at the mismatches

# %%
predictions = pd.DataFrame(data={'text': raw_text, 'encoded_text': enc_text, 'ref_fractions': ref_fractions, 'label': pd_labels, 'pred': pd_predicted})

# %%
predictions.to_pickle('inspire_data_with_reference_fractions_and_num_references/predictions_custom_preprocessing.pkl')

# %%
predictions.head()
# Out:
#                                                 text  \
# 0  Neutron orbit sizes in the isotopes of tin <EN...
# 1  Construction of hyperbolic Riemann surfaces wi...
# 2  Correlated Electron-Nuclear Dynamics with Cond...
# 3  Dependence of halo bias on mass and environmen...
# 4  Noise and Periodic Modulations in Neural Excit...
#
#                                         encoded_text  \
# 0  [17109, 238693, 38823, 232019, 174713, 14067, ...
# 1  [242367, 36948, 157865, 94049, 222424, 178445,...
# 2  [235062, 172846, 135452, 178445, 72694, 222565...
# 3  [214412, 36948, 138296, 19148, 233908, 62786, ...
# 4  [71353, 15913, 214773, 228443, 232019, 120110,...
#
#                                        ref_fractions  label  pred
# 0  (-0.50756806, -0.43275675, 2.602756, 1.2361034...      1     1
# 1  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      0     0
# 2  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      0     0
# 3  (-0.5821015, -0.53982633, 4.1853714, 3.706151,...      1     1
# 4  (-0.50570476, -0.4505913, -0.5509232, -0.03649...      0     0

# %%
predictions[(predictions.label == 2) &  (predictions.pred == 0)]
# Out:
#                                                     text  \
# 340    Clebsch–Gordan coefficients of discrete groups...
# 2622   Untangling knots via reaction-diffusion dynami...
# 3401   Evolution and metric signature change of maxim...
# 3415   Asymptotic expansions of the Witten-Reshetikhi...
# 3472   Comparing Jupiter interior structure models to...
# 3951   New family of potentials with analytical twist...
# 4303   On integral representations and asymptotics of...
# 5878   On the unipotence of autoequivalences of toric...
# 6505   Solving DWF Dirac Equation Using Multisplittin...
# 6509   Unconstrained Summoning <ENDTITLE> We define a...
# 6726   Remark on Y$_4$ moments <ENDTITLE> Qualitative...
# 8015   The Quantum Trihedron <ENDTITLE> The convex hu...
# 8190   Witten Genus and Elliptic genera for proper ac...
# 9817   Homotopy Theoretic Classification of Symmetry ...
# 10500  Magnetic Zero-Modes, Vortices and Cartan Geome...
# 12794  Prethermalization and universal dynamics in ne...
# 13029  Positive Hamiltonians can give purely exponent...
# 13572  Gaussian quantum resource theories <ENDTITLE> ...
# 13931  Error Correction of Quantum Reference Frame In...
# 13970  Sign variation, the Grassmannian, and total po...
# 14281  Sobre a desintegração de prótons em movimento ...
# 14379  Many-body localization and new critical phenom...
# 14796  Numerical Solution of the Boundary Value Probl...
# 15024  Effective computation of traces, determinants,...
# 15286  INFERNO: Inference-Aware Neural Optimisation <...
# 15296  A Theory of Ambulance Chasing <ENDTITLE> Ambul...
# 17359  An Improved Composite Hypothesis Test for Mark...
# 17849  Quantum groups, coherent states, squeezing and...
# 18864  The boundary of the chronology violating set <...
# 18930  An Improved Composite Hypothesis Test for Mark...
# 21600  Renormalization Group transformations of the d...
# 21686  Elementary matrix factorizations over B\'ezout...
# 23143  Elementary matrix factorizations over B\'ezout...
# 24189  Creative Telescoping for Holonomic Functions <...
# 24394  Twisted hyperk\"ahler symmetries and hyperholo...
# 25622  High performance vibration isolation using spr...
# 26215  The Polynomial Form of the Scattering Equation...
# 26721  Once More on Coulomb-Nuclear Interference <END...
# 26847  Many-body localization and new critical phenom...
# 26928  Prethermalization and universal dynamics in ne...
# 27109  The $\beta$-function for Yukawa theory at larg...
# 29050  Reconsidering seismological constraints on the...
# 29381  Stability conditions and cluster varieties fro...
# 29672  A Variational Approach to the Structure and Th...
# 30049  Error Correction of Quantum Reference Frame In...
# 31013  Does the diffraction cone shrinkage with energ...
# 31235  Estimating spacetime parameters with a quantum...
# 31431  Algebraicity and Asymptotics: An explosion of ...
# 31484  Asymptotic expansions of the Witten-Reshetikhi...
# 31495  The boundary of the chronology violating set <...
# 31617  Rings: an efficient Java/Scala library for pol...
# 31924  Formal Theory Developments <ENDTITLE> We give ...
# 32267  Renormalization of Sparse Disorder in the Isin...
# 32360  Canonical quantization of lattice Higgs-Yang-M...
# 32656  $\mathcal{N}=2$ Super-Teichm\"uller Theory <EN...
# 32750  A Numerical Approach to Optimal Coherent Quant...
# 33048  Period preserving nonisospectral flows and the...
# 33756  Intersection cohomology of moduli spaces of sh...
# 34601  Currents for Arbitrary Helicity <ENDTITLE> Usi...
# 35739  A Numerical Approach to Optimal Coherent Quant...
# 35763  An exponential correction to Starobinsky's inf...
# 36107  Non-orthogonal Multiple Access for High-reliab...
# 36470  Visualization of Publication Impact <ENDTITLE>...
# 39215  Casimir interaction of strained graphene <ENDT...
# 39659  Visualization of Publication Impact <ENDTITLE>...
# 40455  Combining TMD factorization and collinear fact...
# 43416  Sensitivity coefficients to variation of funda...
# 44377  Laurent positivity of quantized canonical base...
# 44405  Single charge exchange in collision of fast pr...
# 44414  Non-orthogonal Multiple Access for High-reliab...
# 44911  Cosmic secrets <ENDTITLE> We see objects in fr...
# 45269  Path-sum solution of the Weyl Quantum Walk in ...
# 45545     Understanding Color Confinement <ENDTITLE> EPJ
# 45929  Creative Telescoping for Holonomic Functions <...
# 46289  Separability in 1+1 Dimensions in Classical No...
# 46315  A Potts Neuron Approach to Communication Routi...
# 46879  On the local isometric embedding of trapped su...
# 47788  art@CMS SciArt Workshops <ENDTITLE> Recent dev...
# 49679  Inflation due to non-minimal coupling of $f(R)...
# 49931  A Variational Approach to the Structure and Th...
# 50555  Infinitely many new families of complete cohom...
# 50712  Three-Body $B^0_{(s)}$ to $\phi \pi^+ \pi^-$ D...
# 50790  Topological properties of ferromagnetic superc...
# 51827  Stability conditions and cluster varieties fro...
# 51938  Problems with variable Hilbert space in quantu...
# 52214  General Construction of Tubular Geometry <ENDT...
# 53877  Separability in 1+1 Dimensions in Classical No...
# 53896  Unconstrained Summoning <ENDTITLE> We define a...
# 54043  On integral representations and asymptotics of...
# 54148  Effective computation of traces, determinants,...
# 54870  Perturbations and quantum relaxation <ENDTITLE...
#
#                                             encoded_text  \
# 340    [181307, 73104, 36948, 57848, 243781, 232019, ...
# 2622   [148204, 242901, 210225, 190485, 135452, 36948...
# 3401   [56144, 15913, 221088, 153849, 150020, 36948, ...
# 3415   [155385, 194127, 36948, 174713, 161247, 123343...
# 3472   [30232, 149083, 244818, 226361, 11466, 8019, 1...
# 3951   [161778, 237371, 36948, 110460, 178445, 214147...
# 4303   [233908, 136846, 83981, 15913, 168694, 36948, ...
# 5878   [233908, 174713, 1, 36948, 110810, 36948, 1898...
# 6505   [238404, 14684, 126084, 1139, 76763, 35374, 12...
# 6509   [18786, 1, 163507, 224290, 22416, 138034, 1, 2...
# 6726   [150026, 233908, 187625, 31604, 117683, 147623...
# 8015   [174713, 72052, 36287, 163507, 174713, 152315,...
# 8190   [137174, 193585, 15913, 172243, 193585, 146041...
# 9817   [59494, 190755, 4738, 36948, 178923, 191769, 8...
# 10500  [26688, 218146, 86281, 15913, 126841, 182964, ...
# 12794  [154457, 15913, 78873, 135452, 232019, 190186,...
# 13029  [181072, 96397, 26774, 219545, 83977, 185321, ...
# 13572  [226928, 72052, 70302, 230616, 163507, 224290,...
# 39659  [73615, 36948, 123698, 108957, 163507, 208659,...
# 40455  [116775, 136000, 162445, 15913, 194586, 162445...
# 43416  [106047, 73104, 8019, 38437, 36948, 234341, 12...
# 44377  [56908, 153608, 36948, 189057, 134767, 244199,...
# 44405  [198603, 165195, 104826, 232019, 58462, 36948,...
# 44414  [212425, 133099, 15184, 146041, 1, 15913, 3195...
# 44911  [69916, 98599, 163507, 224290, 181228, 189206,...
# 45269  [18202, 205014, 36948, 174713, 189324, 72052, ...
# 45545  [117514, 194610, 10691, 163507, 36802, 0, 0, 0...
# 45929  [122438, 158271, 146041, 207631, 204808, 16350...
# 46289  [136380, 232019, 31604, 145257, 147623, 84378,...
# 46315  [138034, 139362, 65587, 129044, 8019, 229074, ...
# 46879  [233908, 174713, 225170, 97703, 15491, 36948, ...
# 47788  [67233, 115992, 199615, 1, 97514, 163507, 2250...
# 49679  [179580, 122068, 8019, 159118, 1325, 36948, 85...
# 49931  [138034, 150042, 129044, 8019, 174713, 226361,...
# 50555  [680, 198032, 161778, 237371, 36948, 196052, 1...
# 50712  [93447, 85933, 109669, 31604, 145257, 147623, ...
# 50790  [111846, 36783, 36948, 3091, 51326, 163507, 13...
# 51827  [2863, 23674, 15913, 4932, 172534, 201191, 131...
# 51938  [78746, 178445, 159269, 142648, 127909, 232019...
# 52214  [3602, 242367, 36948, 186332, 182964, 163507, ...
# 53877  [136380, 232019, 31604, 145257, 147623, 84378,...
# 53896  [18786, 1, 163507, 224290, 22416, 138034, 1, 2...
# 54043  [233908, 136846, 83981, 15913, 168694, 36948, ...
# 54148  [36145, 113342, 36948, 81965, 18071, 15913, 31...
# 54870  [74744, 15913, 72052, 70594, 163507, 224290, 2...
#
#                                            ref_fractions  label  pred
# 340    (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 2622   (-0.07278954, 1.212665, -0.5509232, 0.27574164...      2     0
# 3401   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 3415   (-0.5294141, -0.3884906, -0.37943667, -0.36108...      2     0
# 3472   (-0.5821015, -0.62245136, 0.609469, 0.7005839,...      2     0
# 3951   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 4303   (-0.24256021, 0.3490553, -0.5509232, 0.0101637...      2     0
# 5878   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 6505   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 6509   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 6726   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 8015   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 8190   (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 9817   (-0.24256021, 0.42853922, -0.32989612, 0.17492...      2     0
# 10500  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 12794  (0.025025347, 0.12397852, 0.19010304, 0.209440...      2     0
# 13029  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 13572  (-0.55026954, -0.56641006, 0.17432193, 0.41807...      2     0
# 13931  (-0.50168383, 0.04922203, 0.10343331, 0.301522...      2     0
# 13970  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 14281  (-0.5821015, -0.5700195, -0.47321838, -0.63074...      2     0
# 14379  (0.32929888, 0.88337046, -0.114685535, -0.0412...      2     0
# 14796  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 15024  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 15286  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 15296  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 17359  (-0.5821015, -0.62245136, -0.30226773, -0.6307...      2     0
# 17849  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 18864  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 18930  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 21600  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 21686  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 23143  (-0.29561353, 1.0871043, -0.5509232, -0.278884...      2     0
# 24189  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 24394  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 25622  (0.8069312, 0.21765661, -0.09882235, -0.264238...      2     0
# 26215  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 26721  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 26847  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 26928  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 27109  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 29050  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 29381  (-0.32744554, 0.5007771, -0.13649742, -0.02588...      2     0
# 29672  (-0.5821015, -0.4014884, -0.3437103, -0.057715...      2     0
# 30049  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 31013  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 31235  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 31431  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 31484  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 31495  (0.46835446, 0.5340349, 1.6248122, 1.0477886, ...      2     0
# 31617  (-0.304295, 1.8273001, -0.437898, -0.50708485,...      2     0
# 31924  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 32267  (-0.19032308, 0.7762516, 0.21417056, 0.6930840...      2     0
# 32360  (-0.32744554, -0.62245136, -0.5509232, -0.6307...      2     0
# 32656  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 32750  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 33048  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 33756  (-0.02648845, 0.8885955, -0.24952264, 0.006933...      2     0
# 34601  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 35739  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 35763  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 36107  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 36470  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 39215  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 39659  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 40455  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 43416  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 44377  (0.23279767, 0.5064496, -0.21938257, -0.073105...      2     0
# 44405  (-0.5821015, -0.62245136, 0.014202873, -0.3633...      2     0
# 44414  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 44911  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 45269  (0.07272817, 0.19943307, -0.37331215, -0.19656...      2     0
# 45545  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 45929  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 46289  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 46315  (-0.5821015, -0.62245136, 0.07071548, -0.63074...      2     0
# 46879  (-0.34084848, 0.004798379, 0.10343331, 2.17894...      2     0
# 47788  (-0.36382496, -0.62245136, -0.5509232, -0.6307...      2     0
# 49679  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 49931  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 50555  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 50712  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 50790  (-0.5821015, -0.4505913, -0.15307444, 1.003448...      2     0
# 51827  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 51938  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 52214  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 53877  (-0.17465194, 1.2336377, -0.5509232, -0.630744...      2     0
# 53896  (-0.304295, -0.39540684, -0.09882235, 0.694055...      2     0
# 54043  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0
# 54148  (-0.26597685, 1.0904683, -0.122206874, 0.14276...      2     0
# 54870  (-0.5821015, -0.62245136, -0.5509232, -0.63074...      2     0

# %%
plt.figure(figsize=(16, 9))
plt.subplot(311)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,0])
plt.subplot(312)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,1])
plt.subplot(313)
plt.plot(model.fc.weight.cpu().detach().numpy().T[:,2])

# %%
plt.figure(figsize=(16, 9))
plt.subplot(611)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,0])
plt.subplot(612)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,1])
plt.subplot(613)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,2])
plt.subplot(614)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,3])
plt.subplot(615)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,4])
plt.subplot(616)
plt.plot(model.fc_reference_fraction1.weight.cpu().detach().numpy()[:,5])

# %%
model

# %%
(
    (model.fc.weight.cpu().detach().numpy().T[:,0].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,0].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,0].mean()
    ),
    (model.fc.weight.cpu().detach().numpy().T[:,1].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,1].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,1].mean()
    ),
    (model.fc.weight.cpu().detach().numpy().T[:,2].mean(), 
     model.fc.weight.cpu().detach().numpy().T[:800,2].mean(),
     model.fc.weight.cpu().detach().numpy().T[800:,2].mean()
    )
)

# %%
plt.figure(figsize=(16, 9))
plt.imshow(model.fc.weight.cpu().detach().numpy(), aspect='auto')
